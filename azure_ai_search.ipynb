# %% [markdown]
# # Azure AI Search: vector search, step by step

# %% [markdown]
# ## Setup API client

# %%
import os

import azure.identity
import dotenv
from azure.search.documents.indexes import SearchIndexClient

dotenv.load_dotenv("prod.env")

AZURE_SEARCH_SERVICE = os.getenv("AZURE_SEARCH_SERVICE")
AZURE_SEARCH_ENDPOINT = f"https://{AZURE_SEARCH_SERVICE}.search.windows.net"

azure_credential = azure.identity.AzureDeveloperCliCredential(tenant_id=os.getenv("AZURE_TENANT_ID"))
index_client = SearchIndexClient(endpoint=AZURE_SEARCH_ENDPOINT, credential=azure_credential)

# %%
print(AZURE_SEARCH_SERVICE)
print(AZURE_SEARCH_ENDPOINT)
print(os.getenv("AZURE_TENANT_ID"))
# Out:
# search-service-ai-prod
# https://search-service-ai-prod.search.windows.net
# 12b173d3-a7a1-4331-9fa4-69c3ab228e5c

# %% [markdown]
# ## Search a tiny index
#
# ### Create index

# %%
from azure.search.documents.indexes.models import (
    HnswAlgorithmConfiguration,
    HnswParameters,
    SearchField,
    SearchFieldDataType,
    SearchIndex,
    SimpleField,
    VectorSearch,
    VectorSearchAlgorithmKind,
    VectorSearchProfile,
)

AZURE_SEARCH_TINY_INDEX = "teeenytinyindex"

index = SearchIndex(
    name=AZURE_SEARCH_TINY_INDEX, 
    fields=[
        SimpleField(name="id", type=SearchFieldDataType.String, key=True),
        SearchField(name="embedding", 
                    type=SearchFieldDataType.Collection(SearchFieldDataType.Single), 
                    searchable=True, 
                    vector_search_dimensions=3,
                    vector_search_profile_name="embedding_profile")
    ],
    vector_search=VectorSearch(
        algorithms=[HnswAlgorithmConfiguration( # Hierachical Navigable Small World, IVF
                            name="hnsw_config",
                            kind=VectorSearchAlgorithmKind.HNSW,
                            parameters=HnswParameters(metric="cosine"),
                        )],
        profiles=[VectorSearchProfile(name="embedding_profile", algorithm_configuration_name="hnsw_config")]
    )
)

index_client.create_index(index)

# %% [markdown]
# ### Insert a few documents with tiny vectors

# %%
from azure.search.documents import SearchClient

search_client = SearchClient(AZURE_SEARCH_ENDPOINT, AZURE_SEARCH_TINY_INDEX, credential=azure_credential)
search_client.upload_documents(documents=[
    {"id": "1", "embedding": [1, 2, 3]},
    {"id": "2", "embedding": [1, 1, 3]},
    {"id": "3", "embedding": [4, 5, 6]}])

# %% [markdown]
# ### Search using vector similarity

# %%
from azure.search.documents.models import VectorizedQuery

r = search_client.search(search_text=None, vector_queries=[
    VectorizedQuery(vector=[-2, -1, -1], k_nearest_neighbors=3, fields="embedding")])
for doc in r:
    print(f"id: {doc['id']}, score: {doc['@search.score']}")

# %% [markdown]
# ## Search a larger index

# %%
import azure.identity
import dotenv
import openai

dotenv.load_dotenv()

# Initialize Azure search variables
AZURE_SEARCH_SERVICE = os.getenv("AZURE_SEARCH_SERVICE")
AZURE_SEARCH_ENDPOINT = f"https://{AZURE_SEARCH_SERVICE}.search.windows.net"

# Set up OpenAI client based on environment variables
dotenv.load_dotenv()
AZURE_OPENAI_SERVICE = os.getenv("AZURE_OPENAI_SERVICE")
AZURE_OPENAI_ADA_DEPLOYMENT = os.getenv("AZURE_OPENAI_ADA_DEPLOYMENT")

token_provider = azure.identity.get_bearer_token_provider(azure_credential, "https://cognitiveservices.azure.com/.default")

openai_client = openai.AzureOpenAI(
    api_version="2024-08-01-preview",
    azure_endpoint=f"https://{AZURE_OPENAI_SERVICE}.openai.azure.com",
    azure_ad_token_provider=token_provider)

def get_embedding(text):
    get_embeddings_response = openai_client.embeddings.create(model=AZURE_OPENAI_ADA_DEPLOYMENT, input=text)
    return get_embeddings_response.data[0].embedding

# %%
AZURE_SEARCH_FULL_INDEX = "index-docs-ai-score-test"
search_client = SearchClient(AZURE_SEARCH_ENDPOINT, AZURE_SEARCH_FULL_INDEX, credential=azure_credential)

search_query = "learning about underwater activities"
search_vector = get_embedding(search_query)

r = search_client.search(search_text=None, top=5, vector_queries=[
    VectorizedQuery(vector=search_vector, k_nearest_neighbors=5, fields="embedding")])

for doc in r:
    content = doc["content"].replace("\n", " ")[:150]
    print(f"Score: {doc['@search.score']:.5f}\tContent:{content}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 AZURE_SEARCH_FULL_INDEX = "index-docs-ai-score-test"
# ----> 2 search_client = SearchClient(AZURE_SEARCH_ENDPOINT, AZURE_SEARCH_FULL_INDEX, credential=azure_credential)
#       4 search_query = "learning about underwater activities"
#       5 search_vector = get_embedding(search_query)
#
# NameError: name 'SearchClient' is not defined

# %%
AZURE_SEARCH_FULL_INDEX = "index-archive-exporter-2-keyword-no-skills-kajetan"

# %%
AZURE_SEARCH_FULL_INDEX = "index-docs-ai-score-test"

# %%
from azure.search.documents import SearchClient

search_client = SearchClient(AZURE_SEARCH_ENDPOINT, AZURE_SEARCH_FULL_INDEX, credential=azure_credential)

# %%
results =  search_client.search(
    query_type='simple',
    search_text="ArchiveStatusId" ,
    select='content',
    search_fields=['content'],
    include_total_count=True
    )

print ('Total Documents Matching Query:', results.get_count())

for result in results:
    print(result["@search.score"])
    print(result["content"])
# Out:
# Total Documents Matching Query: 0

# %%
results =  search_client.search(
    query_type='simple',
    search_text="g2s" ,
    select='content',
    search_fields=['content'],
    include_total_count=True
    )

print ('Total Documents Matching Query:', results.get_count())

for result in results:
    print(result["@search.score"])
    print(result["content"])
# Out:
# Total Documents Matching Query: 66
# 5.606973
#  Valid values depend on the game category. For details,</td></tr><tr><td></td><td></td></tr></table></figure>
# www.comtradegaming.com
# sCore
# 98COMTRADE GAMING
# sCore NCEMS Integration Guide
# <figure><table><tr><th>Attribute</th><th>Data type</th><th>Description</th></tr><tr><td></td><td></td><td>see game category-specific sections in this chapter.</td></tr><tr><td>transType</td><td>t_transType</td><td>Standardized code* for type of the transaction (meter). Valid values depend on the game category. For details, see game category-specific sections in this chapter.</td></tr><tr><td>movementValue</td><td>t_money</td><td>Value of the movement or the meter.</td></tr></table></figure>
# * The set of standardized codes for meter domain and meter type (valid values of the t_transClass and t_transType enumeration data types) is defined in the G2S protocol specification. A gaming terminal, connected to the operator's CMS either directly or through a SMIB, should report all required meters. In case the CMS does not interpret those meters as G2S meters, you must map SAS meter domain and meter type codes to the corresponding G2S
# 5.554595
# /> <modelDefinition transClass="G2S_cabinet" transType="G2S_egmPaidGameWonAmt" /> <modelDefinition transClass="G2S_cabinet" transType="G2S_handPaidGameWonAmt" /> <modelDefinition transClass="G2S_cabinet" transType="G2S_gamesSinceInitCnt" /> <modelDefinition transClass="G2S_gamePlay" transType="G2S_wageredAmt" /> <modelDefinition transClass="G2S_gamePlay" transType="G2S_wonCnt" /> <modelDefinition transClass="G2S_gamePlay" transType="G2S_lostCnt" /> <modelDefinition transClass="G2S_gamePlay" transType="G2S_theoPaybackAmt" /> <modelDefinition transClass="G2S_gamePlay" transType="G2S_avgPaybackPct" /> </modelDefinitionList> <ggrCalculationList> <ggrCalculation transClass="G2S cabinet" transType="G2S_wageredCashableAmt" functionType="RRI_add" /> _ _
# <ggrCalculation transClass="G2S cabinet" transType="G2S_egmPaidGameWonAmt" functionType="RRI_subtract" /> <ggrCalculation transClass="G2S cabinet" transType="G2S_handPaidGameWonAmt" _
# Page 590
# @ 2020 International Gaming Standards Association (IGSA)
# Released: TBDIGSA Regulatory Reporting Interface V1.0 DRAFT 18
# 7 Land-Based Games
# functionType="RRI_subtract" /> </ggrCalculationList> </modelConfig> </gamingReport>
# 7.
# 5.5213943
#  The gaming terminal, connected to the operator's CMS either directly or through a SMIB, should report all required events. In case the CMS does not interpret those events as G2S events, you must map SAS event type codes to the corresponding G2S event type codes first. See SAS-to-G2S mapping of event type codes on page 176.
# The following table lists valid values of the t_eventCode enumeration data type (event type codes from the G2S protocol specification):
# <figure><table><tr><th>Event type (G2S protocol)</th><th>Description</th></tr><tr><td>G2S_JPE104</td><td>Handpay keyed off.</td></tr><tr><td>G2S_NAE114</td><td>Note stacked.</td></tr><tr><td>G2S_BNE104</td><td>Bonus award paid.</td></tr><tr><td>G2S_CBE307</td><td>Cabinet door opened.</td></tr><tr><td>G2S_CBE305</td><td>Auxiliary door opened.</td></tr><tr><td>G2S_CBE303</td><td>Logic door opened.</td></tr><tr><td>G2S_CBE308</td><td>Cabinet door closed.</td></tr><tr><td>G2S_CBE320</td><td>Operator&#x27;s cabinet reset.</td></tr><tr><td>G2S_CBE306</td><td>Auxiliary door closed.
# 5.1463356
# 13 G2S Event Codes
# When events originate from endpoints communicating via the G2S protocol, the Event Codes reported using this specification should be the same event codes reported through the G2S protocol. The accompanying text should be set to the text that was reported with the event in the G2S protocol. G2S class-level meter information that is reported with events should be included as snapshot meters. G2S status and transaction information that is reported with events should be included as associated data.
# 7B.5.14 S2S Event Codes
# When events originate from endpoints communicating via the S2S protocol, the Event Codes reported using this specification should be the same event codes reported through the S2S protocol. The accompanying text should be set to the text that was reported with the event in the S2S protocol. S2S class-level meter information that is reported with events should be included as snapshot meters.
# 7B.5.15 SAS Event Codes
# When events originate from games communicating via the SAS protocol, the Event Codes reported using this specification should be constructed by appending the
# 5.140403
# March 2024</td></tr><tr><td>SCB</td><td>Standard Chartered Bank Uganda</td><td>8 March 2024</td></tr></table></figure>
# When the gaming regulator acknowledges expansion of the list with new entries, you may expect an update to be published in the next edition of the integration guide.
# A.4 SAS-to-G2S mapping of meter domain and meter type codes
# For meters in land-based gaming terminals, SAS protocol-defined meter domain and meter type codes map to the G2S protocol-defined ones as follows:
# <figure><table><tr><th>G2S class*</th><th>G2S name*</th><th>G2S scale</th><th>SAS code</th><th>Dims.</th><th>Description</th><th>SAS scale</th></tr><tr><td colSpan=5>* Values in this column should be appended to the &quot;G2S_&quot; prefix.</td><td></td><td></td></tr><tr><td>bonus</td><td>cashableInAmt</td><td>10000</td><td>0x00AE</td><td>class</td><td>Bonus cashable transfer to gaming machine (cents).</td><td>100</td></tr><tr><td>bonus</td><td>promoInAmt</td><td>10000</td><td>0x00B0</td><td>class</td><td>Bonus non-restricted transfers to gaming machine (cents).</td><td>100</td></tr><tr><td>bonus</td><td>transferInCnt</td><td>1</td><td>0x00AF + 0x00B1</td><td>class</td><td>Bonus transfers to
# 5.119441
# com
# sCore
# 173sCore NCEMS Integration Guide
# COMTRADE GAMING
# <figure><table><tr><th>G2S class*</th><th>G2S name*</th><th>G2S scale</th><th>SAS code</th><th>Dims.</th><th>Description</th><th>SAS scale</th></tr><tr><td colSpan=5>* Values in this column should be appended to the &quot;G2S_&quot; prefix.</td><td colSpan=2></td></tr><tr><td>cabinet</td><td>egmPaidProgWonAmt</td><td>10000</td><td>0x001D</td><td>class, game, denom</td><td>Total machine paid progressive win (credits).</td><td>AD</td></tr><tr><td>cabinet</td><td>handPaidProgWonAmt</td><td>10000</td><td>0x0020</td><td>class, game, denom</td><td>Total attendant paid progressive win (credits).</td><td>AD</td></tr><tr><td>cabinet</td><td>handPaidBonusWonAmt</td><td>10000</td><td>0x0021</td><td>class, game, denom</td><td>Total attendant paid external bonus win (credits).</td><td>AD</td></tr><tr><td>cabinet</td><td>handPaidCancelAmt</td><td>10000</td><td>0x0003</td><td>class</td><td>Total hand paid cancelled (credits).</td><td>AD</td></tr><tr><td>cabinet</td><td>gamesSinceInitCnt</td><td>1</td><td>0x0005</td><td>class, game, denom</td><td>Games played.
# 5.019347
# </td></tr><tr><td>4D</td><td>Bills_Info_Accepted_002_4D</td><td>G2S_NAE114</td><td>Note stacked.</td></tr></table></figure>
# www.comtradegaming.com
# sCore
# 176sCore NCEMS Integration Guide
# COMTRADE GAMING
# <figure><table><tr><th>SAS event type ID</th><th>SAS event type context*</th><th>G2S event type code</th><th>G2S event type description</th></tr><tr><td>4E</td><td>Bills_Info_Accepted_500_4E</td><td>G2S_NAE114</td><td>Note stacked.</td></tr><tr><td>4F</td><td>Bills_Info_Accepted_Any_4F</td><td>G2S_NAE114</td><td>Note stacked.</td></tr><tr><td>50</td><td>Bills_Info_Accepted_200_50</td><td>G2S_NAE114</td><td>Note stacked.</td></tr><tr><td>69</td><td>AFT_Info_TransferCompleted_69</td><td>G2S_BNE104</td><td>Bonus award paid.</td></tr><tr><td>11</td><td>Doors_Tilt_DoorOpened_Main_11</td><td>G2S_CBE307</td><td>Cabinet door opened.</td></tr><tr><td>1D</td><td>Doors_Tilt_DoorOpened_Belly_1D</td><td>G2S_CBE305</td><td>Auxiliary door opened.</td></tr><tr><td>15</td><td>Doors_Tilt_DoorOpened_CardCage_15</td><td>G2S_CBE303</td><td>Logic door opened.
# 4.987217
# com
# sCore
# 174sCore NCEMS Integration Guide
# COMTRADE GAMING
# <figure><table><tr><th>G2S class*</th><th>G2S name*</th><th>G2S scale</th><th>SAS code</th><th>Dims.</th><th>Description</th><th>SAS scale</th></tr><tr><td colSpan=4>* Values in this column should be appended to the &quot;G2S_&quot; prefix.</td><td></td><td></td><td></td></tr><tr><td></td><td></td><td></td><td>0x0020</td><td>game, denom</td><td>progressive win (credits) + Total attendant paid progressive win (credits).</td><td></td></tr><tr><td>voucher</td><td>cashableInAmt</td><td>10000</td><td>0x0029</td><td>class</td><td>Total regular cashable ticket in (credits) [1.A].</td><td>AD</td></tr><tr><td>voucher</td><td>cashableInCnt</td><td>1</td><td>0x0035</td><td>class</td><td>Total cashable ticket in (quantity) [2.A].</td><td>1</td></tr><tr><td>voucher</td><td>promoInAmt</td><td>10000</td><td>0x002B</td><td>class</td><td>Total non-restricted promotional ticket in (credits) [3.A].</td><td>AD</td></tr><tr><td>voucher</td><td>promoInCnt</td><td>1</td><td>0x0037</td><td>class</td><td>Total non-restricted promotional ticket in (quantity) [4.
# 4.987217
# com
# sCore
# 175sCore NCEMS Integration Guide
# COMTRADE GAMING
# <figure><table><tr><th>G2S class* * Values in this</th><th>G2S name*
# column should be appended to</th><th>G2S scale
# the &quot;G2S_&quot;</th><th>SAS code
# prefix.</th><th>Dims.</th><th>Description</th><th>SAS scale</th></tr><tr><td></td><td></td><td></td><td></td><td></td><td>transfers to gaming machine (cents).</td><td></td></tr><tr><td>wat</td><td>transferInCnt</td><td>1</td><td>0x00A1 + 0x00A3 + 0x00A5</td><td>class</td><td>In-house cashable, restricted, non-restricted transfers to gaming machine (quantity).</td><td>1</td></tr><tr><td>wat</td><td>cashableOutAmt</td><td>10000</td><td>0x00B8</td><td>class</td><td>In-house cashable transfers to host (cents).</td><td>AD</td></tr><tr><td>wat</td><td>promoOutAmt</td><td>10000</td><td>0x00BA</td><td>class</td><td>In-house restricted transfers to host (cents).</td><td>AD</td></tr><tr><td>wat</td><td>nonCashOutAmt</td><td>10000</td><td>0x00BC</td><td>class</td><td>In-house nonrestricted transfers to host (cents).</td><td>AD</td></tr><tr><td>wat</td><td>transferOutCnt</td><td>1</td><td>0x00B9 + 0x00BA + 0x00BD</td><td>class</td><td>In-house
# 4.945564
# 14 Accounting Model for G2S Smart Card Class (G2S_smartCard)
# <figure><table><tr><th>Transaction Type</th><th>Description</th><th>Type</th></tr><tr><td>G2S_cashableInAmt</td><td>Value of cashable credits transferred in.</td><td>Amount</td></tr><tr><td>G2S_promoInAmt</td><td>Value of promo credits transferred in.</td><td>Amount</td></tr><tr><td>G2S_nonCashInAmt</td><td>Value of non-cashable credits transferred in.</td><td>Amount</td></tr><tr><td>G2S transferInCnt</td><td>Count of transfers in.</td><td>Count</td></tr></table></figure>
# Page 652
# @ 2020 International Gaming Standards Association (IGSA)
# Released: TBDIGSA Regulatory Reporting Interface V1.0 DRAFT 18
# 7B Land-Based Gaming Machines
# Table 7B.14 Accounting Model for G2S Smart Card Class (G2S_smartCard)
# <figure><table><tr><th>Transaction Type</th><th>Description</th><th>Type</th></tr><tr><td>G2S_cashableOutAmt</td><td>Value of cashable credits transferred out.</td><td>Amount</td></tr><tr><td>G2S_promoOutAmt</td><td>Value of promo credits transferred out.</td><td>Amount</td></tr><tr><td>G2S_nonCashOutAmt</td><td>Value of non-cashable credits transferred out.
# 4.8317785
# codes
# For meters in land-based gaming terminals, SAS protocol-defined meter domain and meter type codes map to the G2S protocol-defined ones as follows:
# <figure><table><tr><th>G2S class*</th><th>G2S name*</th><th>G2S scale</th><th>SAS code</th><th>Dims.</th><th>Description</th><th>SAS scale</th></tr><tr><td colSpan=5>* Values in this column should be appended to the &quot;G2S_&quot; prefix.</td><td></td><td></td></tr><tr><td>bonus</td><td>cashableInAmt</td><td>10000</td><td>0x00AE</td><td>class</td><td>Bonus cashable transfer to gaming machine (cents).</td><td>100</td></tr><tr><td>bonus</td><td>promoInAmt</td><td>10000</td><td>0x00B0</td><td>class</td><td>Bonus non-restricted transfers to gaming machine (cents).</td><td>100</td></tr><tr><td>bonus</td><td>transferInCnt</td><td>1</td><td>0x00AF + 0x00B1</td><td>class</td><td>Bonus transfers to gaming machine that include cashable, non-restricted amounts (quantity).</td><td>1</td></tr><tr><td>cabinet</td><td>playerCashableAmt</td><td>10000</td><td>0x000C</td><td>class</td><td>Current credits.</td><td>AD **</td></tr><tr><td>cabinet</td><td>playerNonCashAmt</td><td>10000</td><td>0x001B</td><td>class</td><td>Current restricted credits.
# 4.6382093
#
# The following table lists valid values of the t_eventCode enumeration data type (event type codes from the G2S protocol specification):
# <figure><table><tr><th>Event type (G2S protocol)</th><th>Description</th></tr><tr><td>G2S_JPE104</td><td>Handpay keyed off.</td></tr><tr><td>G2S_NAE114</td><td>Note stacked.</td></tr><tr><td>G2S_BNE104</td><td>Bonus award paid.</td></tr><tr><td>G2S_CBE307</td><td>Cabinet door opened.</td></tr><tr><td>G2S_CBE305</td><td>Auxiliary door opened.</td></tr><tr><td>G2S_CBE303</td><td>Logic door opened.</td></tr><tr><td>G2S_CBE308</td><td>Cabinet door closed.</td></tr><tr><td>G2S_CBE320</td><td>Operator&#x27;s cabinet reset.</td></tr><tr><td>G2S_CBE306</td><td>Auxiliary door closed.</td></tr><tr><td>G2S_CBE304</td><td>Logic door closed.</td></tr><tr><td>G2S_CBE325</td><td>EGM power-up or restart.</td></tr><tr><td>G2S_CBE206</td><td>Operator menu activated.</td></tr><tr><td>G2S_CBE208</td><td>Meters/audit mode initiated.</td></tr><tr><td>G2S_CBE317</td><td>Power-off - logic door opened.</td></tr></table></figure>
# www.comtradegaming.com
# sCore
# 116sCore NCEMS Integration Guide
# COMTRADE GAMING
# <figure><table><tr><th>Event type (G2S protocol)
# 4.6382093
# of event type codes
# For events occurring in land-based gaming terminals, SAS protocol-defined event type codes map to the G2S protocol-defined ones as follows:
# <figure><table><tr><th>SAS event type ID</th><th>SAS event type context*</th><th>G2S event type code</th><th>G2S event type description</th></tr><tr><td>51</td><td>HandPay_Tilt_Pending_51</td><td>G2S_JPE101</td><td>Handpay pending.</td></tr><tr><td>52</td><td>HandPay_Info_Reset_52</td><td>G2S_JPE104</td><td>Handpay keyed off.</td></tr><tr><td>47</td><td>Bills_Info_Accepted_001_47</td><td>G2S_NAE114</td><td>Note stacked.</td></tr><tr><td>48</td><td>Bills_Info_Accepted_005_48</td><td>G2S_NAE114</td><td>Note stacked.</td></tr><tr><td>49</td><td>Bills_Info_Accepted_010_49</td><td>G2S_NAE114</td><td>Note stacked.</td></tr><tr><td>4A</td><td>Bills_Info_Accepted_020_4A</td><td>G2S_NAE114</td><td>Note stacked.</td></tr><tr><td>4B</td><td>Bills_Info_Accepted_050_4B</td><td>G2S_NAE114</td><td>Note stacked.</td></tr><tr><td>4C</td><td>Bills_Info_Accepted_100_4C</td><td>G2S_NAE114</td><td>Note stacked.</td></tr><tr><td>4D</td><td>Bills_Info_Accepted_002_4D</td><td>G2S_NAE114</td><td>Note stacked.</td></tr></table></figure>
# www.
# 4.635895
# </td><td>AD **</td></tr><tr><td>cabinet</td><td>playerNonCashAmt</td><td>10000</td><td>0x001B</td><td>class</td><td>Current restricted credits.</td><td>AD</td></tr><tr><td>cabinet</td><td>wageredCashableAmt</td><td>10000</td><td>0x0000 - 0x001A - 0x0019</td><td>class, game, denom</td><td>Total coin in (credits) - Total non-restricted amount played (credits) - Total restricted amount played (credits).</td><td>AD</td></tr><tr><td>cabinet</td><td>wageredPromoAmt</td><td>10000</td><td>0x001A</td><td>class</td><td>Total non-restricted amount played (credits).</td><td>AD</td></tr><tr><td>cabinet</td><td>wageredNonCashAmt</td><td>10000</td><td>0x0019</td><td>class</td><td>Total restricted amount played (credits).</td><td>AD</td></tr><tr><td>cabinet</td><td>handPaidGame WonAmt</td><td>10000</td><td>0x001F</td><td>class, game, denom</td><td>Total attendant paid paytable win, not including progressive or external bonus amounts (credits).</td><td>AD</td></tr></table></figure>
# www.comtradegaming.com
# sCore
# 173sCore NCEMS Integration Guide
# COMTRADE GAMING
# <figure><table><tr><th>G2S class*</th><th>G2S name*</th><th>G2S scale</th><th>SAS
# 4.5697045
# operatorId="myOperator" locationId="myLocation" locationName="My Location" locationAddress="123 Main St, Anywhere, CT" />
# <model jurisdictionCode="ES" operatorId="myOperator" modelId="G2S" /> <terminalConfigDetail terminalName="9876" regulatorId="" onFloor="true" floorLoc="AA1202" currencyCode="EUR" serialNum="ABC_123456" isDeleted="false" fromDateTime="2018-08-30T14:25:39Z" > <slotTerminal egmId="ABC 123456" machineNum="9876" accountingDenom="1" tokenDenom="1.00" machineType="Multigame" yearMade="2018" owner="myOperator" /> </terminalConfigDetail> <terminalRolloverList> <rollover transClass="G2S_cabinet" transType="G2S_wageredCashableAmt" rolloverValue="9999999999999999.99" everIncreasing="true" />
# Released: TBD
# @ 2020 International Gaming Standards Association (IGSA)
# Page 583IGSA Regulatory Reporting Interface V1.0 DRAFT 18
# 7 Land-Based Games
# <rollover transClass="G2S_cabinet" transType="G2S_egmPaidGameWonAmt" rolloverValue="9999999999999999.99" everIncreasing="true" />
# <rollover transClass="G2S_cabinet" transType="G2S_handPaidGameWonAmt" rolloverValue="9999999999999999.99" everIncreasing="true" /> <rollover transClass="G2S_cabinet" transType="G2S_gamesSinceInitCnt"
# 4.553944
# </td><td>AD</td></tr><tr><td>hopper</td><td>currencyOutAmt</td><td>10000</td><td>0x0009</td><td>class</td><td>Total credits paid from hopper.</td><td>AD</td></tr><tr><td>noteAcceptor</td><td>currencyInAmt</td><td>10000</td><td>0x000B</td><td>class</td><td>Total credits from bills accepted.</td><td>AD</td></tr><tr><td>noteAcceptor</td><td>currencyToDropAmt</td><td>10000</td><td>0x0058</td><td>class</td><td>Total credits from bills to drop.</td><td>AD</td></tr><tr><td>noteAcceptor</td><td>currencyToDispAmt</td><td>10000</td><td>0x0063</td><td>class</td><td>Total credits from bills diverter to hopper.</td><td>AD</td></tr><tr><td>progressive</td><td>cashableInAmt</td><td>10000</td><td>0x001D +</td><td>class,</td><td>Total machine paid</td><td>AD</td></tr></table></figure>
# www.comtradegaming.com
# sCore
# 174sCore NCEMS Integration Guide
# COMTRADE GAMING
# <figure><table><tr><th>G2S class*</th><th>G2S name*</th><th>G2S scale</th><th>SAS code</th><th>Dims.</th><th>Description</th><th>SAS scale</th></tr><tr><td colSpan=4>* Values in this column should be appended to the &quot;G2S_&quot; prefix.
# 4.465458
# Door Opened" eventDateTime="2018-05-02T12 : 53: 05Z" />
# <snapshotMeterList endDateTime="2018-05-02T12: 53 : 05Z" > <meter transClass="G2S_cabinet" transType="G2S_wageredCashableAmt" meterValue="555.00" /> <meter transClass="G2S_cabinet" transType="G2S_egmPaidGameWonAmt" meterValue="444.00" /> <meter transClass="G2S_cabinet" transType="G2S_gamesSinceInitCnt" meterValue="111" /> <meter transClass="G2S_gamePlay" transType="G2S_wageredAmt" meterValue="555.00" /> <meter transClass="G2S_gamePlay" transType="G2S_egmPaidGameWonAmt" meterValue="444.00" /> <meter transClass="G2S_gamePlay" transType="G2S_wonCnt" meterValue="55" /> <meter transClass="G2S_gamePlay" transType="G2S_lostCnt" meterValue="56" /> <meter transClass="G2S_gamePlay" transType="G2S_theoPaybackAmt" meterValue="527.25" /> <meter transClass="G2S_gamePlay" transType="G2S_avgPaybackPct" meterValue="9500" /> _
# Page 682
# @ 2020 International Gaming Standards Association (IGSA)
# Released: TBDIGSA Regulatory Reporting Interface V1.0 DRAFT 18
# 7B Land-Based Gaming Machines
# </snapshotMeterList> </landEvent>
# 7B.5.13 G2S Event Codes
# When events originate from endpoints communicating via the G2S protocol, the Event Codes reported using
# 4.417426
# </td><td>AD</td></tr><tr><td>wat</td><td>transferOutCnt</td><td>1</td><td>0x00B9 + 0x00BA + 0x00BD</td><td>class</td><td>In-house transfers to host that include cashable, restricted, non-restricted amounts (quantity).</td><td>1</td></tr></table></figure>
#
#
#
#
# ** Acronym for "accounting denomination".
# A.5 SAS-to-G2S mapping of event type codes
# For events occurring in land-based gaming terminals, SAS protocol-defined event type codes map to the G2S protocol-defined ones as follows:
# <figure><table><tr><th>SAS event type ID</th><th>SAS event type context*</th><th>G2S event type code</th><th>G2S event type description</th></tr><tr><td>51</td><td>HandPay_Tilt_Pending_51</td><td>G2S_JPE101</td><td>Handpay pending.</td></tr><tr><td>52</td><td>HandPay_Info_Reset_52</td><td>G2S_JPE104</td><td>Handpay keyed off.</td></tr><tr><td>47</td><td>Bills_Info_Accepted_001_47</td><td>G2S_NAE114</td><td>Note stacked.</td></tr><tr><td>48</td><td>Bills_Info_Accepted_005_48</td><td>G2S_NAE114</td><td>Note stacked.</td></tr><tr><td>49</td><td>Bills_Info_Accepted_010_49</td><td>G2S_NAE114</td><td>Note stacked.
# 4.215304
# </td><td>AD</td></tr><tr><td>voucher</td><td>nonCashOutCnt</td><td>1</td><td>0x0039</td><td>class</td><td>Total restricted promotional ticket out (quantity) [10.A].</td><td>1</td></tr><tr><td>wat</td><td>cashableInAmt</td><td>10000</td><td>0x00A0</td><td>class</td><td>In-house cashable transfers to gaming machine (cents).</td><td>AD</td></tr><tr><td>wat</td><td>promoInAmt</td><td>10000</td><td>0x00A2</td><td>class</td><td>In-house restricted transfers to gaming machine (cents).</td><td>AD</td></tr><tr><td>wat</td><td>nonCashInAmt</td><td>10000</td><td>0x00A4</td><td>class</td><td>In-house nonrestricted</td><td>AD</td></tr></table></figure>
# www.comtradegaming.com
# sCore
# 175sCore NCEMS Integration Guide
# COMTRADE GAMING
# <figure><table><tr><th>G2S class* * Values in this</th><th>G2S name*
# column should be appended to</th><th>G2S scale
# the &quot;G2S_&quot;</th><th>SAS code
# prefix.</th><th>Dims.</th><th>Description</th><th>SAS scale</th></tr><tr><td></td><td></td><td></td><td></td><td></td><td>transfers to gaming machine (cents).</td><td></td></tr><tr><td>wat</td><td>transferInCnt</td><td>1</td><td>0x00A1 + 0x00A3 +
# 4.1825438
# 2 Accounting Model for Slovenian Gaming Machines (SLO_egm)
# <figure><table><tr><th>Transaction Type</th><th>Description</th><th>Type</th></tr><tr><td>SLO_voucherOutCnt1</td><td>Total number of issued vouchers.</td><td>Count</td></tr><tr><td>SLO_voucherOutAmt1</td><td>Total amount of issued vouchers.</td><td>Amount</td></tr><tr><td>SLO_wat InAmt1</td><td>Total amount of wat transfers to EGM.</td><td>Amount</td></tr><tr><td>SLO_watOutAmt1</td><td>Total amount of wat transfers from EGM.</td><td>Amount</td></tr><tr><td>SLO_jpContribAmt1,4</td><td>Total amount contributed to the progressive pools.</td><td>Amount</td></tr></table></figure>
# 1. Required for Periodic Summary and Interval Reports.
# 2. Required for Near-Real-Time and Real-Time Event Reports
# 3. Credits are expressed in the accounting denomination (accountingDenom) of the EGM.
# 4. Appropriate for Games played on Land-Based Gaming Machines.
# 7B.3.3 G2S Transaction Classes & Transaction Types
# When movements originate from games communicating via the G2S protocol, the Transaction Class and Transaction Type enumerations in the following tables should be reported.
# 4.0666304
# </td><td>Count</td></tr></table></figure>
# Page 650
# @ 2020 International Gaming Standards Association (IGSA)
# Released: TBDIGSA Regulatory Reporting Interface V1.0 DRAFT 18
# 7B Land-Based Gaming Machines
# Table 7B.9 Accounting Model for G2S Progressive Jackpot Class (G2S_progressive)
# <figure><table><tr><th>Transaction Type</th><th>Description</th><th>Type</th></tr><tr><td>G2S_cashableInAmt</td><td>Value of cashable credits transferred in.</td><td>Amount</td></tr><tr><td>G2S_promo InAmt</td><td>Value of promo credits transferred in.</td><td>Amount</td></tr><tr><td>G2S_nonCashInAmt</td><td>Value of non-cashable credits transferred in.</td><td>Amount</td></tr><tr><td>G2S_transferInCnt</td><td>Count of transfers in.</td><td>Count</td></tr><tr><td>G2S_wageredAmt</td><td>Money wagered against games that contribute to the jackpots.</td><td>Amount</td></tr><tr><td>G2S_playedCnt</td><td>Count of the wagers made against games that contribute to the jackpots.</td><td>Count</td></tr></table></figure>
# Table 7B.10 Accounting Model for G2S Bonus Class (G2S_bonus)
# <figure><table><tr><th>Transaction
# 4.0666304
# 13 Accounting Model for G2S Direct Funds Transfer Class (G2S_dft)
# <figure><table><tr><th>Transaction Type</th><th>Description</th><th>Type</th></tr><tr><td>G2S_cashableInAmt</td><td>Value of cashable credits transferred in.</td><td>Amount</td></tr><tr><td>G2S_promo InAmt</td><td>Value of promo credits transferred in.</td><td>Amount</td></tr><tr><td>G2S_nonCashInAmt</td><td>Value of non-cashable credits transferred in.</td><td>Amount</td></tr><tr><td>G2S_transferInCnt</td><td>Count of transfers in.</td><td>Count</td></tr><tr><td>G2S_cashableOutAmt</td><td>Value of cashable credits transferred out.</td><td>Amount</td></tr><tr><td>G2S_promoOutAmt</td><td>Value of promo credits transferred out.</td><td>Amount</td></tr><tr><td>G2S_nonCashOutAmt</td><td>Value of non-cashable credits transferred out.</td><td>Amount</td></tr><tr><td>G2S_transferOutCnt</td><td>Count of transfers out.</td><td>Count</td></tr></table></figure>
# Table 7B.14 Accounting Model for G2S Smart Card Class (G2S_smartCard)
# <figure><table><tr><th>Transaction Type</th><th>Description</th><th>Type</th></tr><tr><td>G2S_cashableInAmt</td><td>Value of cashable credits transferred in.
# 4.0128407
# Classes & Transaction Types
# When movements originate from games communicating via the G2S protocol, the Transaction Class and Transaction Type enumerations in the following tables should be reported. The Transaction Class is listed in parentheses in the title of the table.
# The full accounting model is appropriate for Terminals that support Games played on Land-Based Gaming Machines. However, only a subset of the full accounting model is appropriate for the Games themselves. That subset is contained in the table below entitled Accounting Model for G2S Game Play Class (G2S_gamePlay).
# Table 7B.3 Accounting Model for G2S Cabinet Class (G2S_cabinet)
# <figure><table><tr><th>Transaction Type</th><th>Description</th><th>Type</th></tr><tr><td>G2S_playerCashableAmt</td><td>Value of cashable credit meter.</td><td>Amount</td></tr><tr><td>G2S_playerPromoAmt</td><td>Value of promo credit meter.</td><td>Amount</td></tr><tr><td>G2S_playerNonCashAmt</td><td>Value of non-cashable credit meter.</td><td>Amount</td></tr><tr><td>G2S_wageredCashableAmt</td><td>Cashable credits wagered on the EGM.</td><td>Amount</td></tr><tr><td>G2S_wageredPromoAmt</td><td>Cashable promotional credits wagered on the EGM.
# 4.0128407
#  In case the CMS does not interpret those meters as G2S meters, you must map SAS meter domain and meter type codes to the corresponding G2S equivalents first. See SAS-to-G2S mapping of meter domain and meter type codes on page 173.
# A meterList element must have the following attributes:
# <figure><table><tr><th>Attribute</th><th>Data type</th><th>Description</th></tr><tr><td>statusDateTime</td><td>t_dateTime</td><td>Date and time of the moment when the meter values were captured.</td></tr></table></figure>
# A meterList element must include the following subelements:
# <figure><table><tr><th>Subelement</th><th>Data type</th><th>Description</th></tr><tr><td>meter</td><td>c_meter</td><td>Life-to-date meter value for a gaming terminal.</td></tr></table></figure>
# A meter element must have the following attributes:
# <figure><table><tr><th>Attribute</th><th>Data type</th><th>Description</th></tr><tr><td></td><td></td><td rowSpan=2>Class of the meter. Valid values depend on the game category. For details, see game category-specific sections in this chapter.
# 3.992639
# 6 Accounting Model for G2S Note Acceptor Class (G2S_noteAcceptor)
# <figure><table><tr><th>Transaction Type</th><th>Description</th><th>Type</th></tr><tr><td>G2S_nonCashInAmt</td><td>Value of currency accepted by the EGM recorded as non- cashable credits.</td><td>Amount</td></tr><tr><td>G2S_nonCashToDropAmt</td><td>Value of currency diverted to the note stacker recorded as non-cashable credits.</td><td>Amount</td></tr><tr><td>G2S_nonCashToDispAmt</td><td>Value of currency diverted to the note dispenser recorded as non-cashable credits.</td><td>Amount</td></tr><tr><td>G2S_stackerRemovedCnt</td><td>Count of stacker removals.</td><td>Count</td></tr><tr><td>G2S_powerOffStackerRemovedCnt</td><td>Count of power off stacker removal detections.</td><td>Count</td></tr><tr><td>G2S_powerOffDropDoorOpenCnt</td><td>Count of power off drop door open detections.</td><td>Count</td></tr><tr><td>G2S_illegalDropDoorOpenCnt</td><td>Count of illegal drop door opens.</td><td>Count</td></tr></table></figure>
# Table 7B.7 Accounting Model for G2S Hopper Class (G2S_hopper)
# <figure><table><tr><th>Transaction
# 3.992639
# 12 Accounting Model for G2S Wagering Account Transfer Class (G2S_wat)
# <figure><table><tr><th>Transaction Type</th><th>Description</th><th>Type</th></tr><tr><td>G2S_cashableInAmt</td><td>Value of cashable credits transferred in.</td><td>Amount</td></tr><tr><td>G2S_promo InAmt</td><td>Value of promo credits transferred in.</td><td>Amount</td></tr><tr><td>G2S_nonCashInAmt</td><td>Value of non-cashable credits transferred in.</td><td>Amount</td></tr><tr><td>G2S_transferInCnt</td><td>Count of transfers in.</td><td>Count</td></tr><tr><td>G2S_cashableOutAmt</td><td>Value of cashable credits transferred out.</td><td>Amount</td></tr><tr><td>G2S_promoOutAmt</td><td>Value of promo credits transferred out.</td><td>Amount</td></tr><tr><td>G2S_nonCashOutAmt</td><td>Value of non-cashable credits transferred out.</td><td>Amount</td></tr><tr><td>G2S_transferOutCnt</td><td>Count of transfers out.</td><td>Count</td></tr></table></figure>
# Table 7B.13 Accounting Model for G2S Direct Funds Transfer Class (G2S_dft)
# <figure><table><tr><th>Transaction Type</th><th>Description</th><th>Type</th></tr><tr><td>G2S_cashableInAmt</td><td>Value of cashable credits transferred in.
# 3.935845
# 3 Accounting Model Configuration Example
# The following example demonstrates the construction of an element using the c_modelConfig complex data type.
# <gamingReport version="1.0" jurisdictionCode="ES" operatorId="myOperator" submitterId="ABC" partitionId="1" periodType="RRI_day" periodStart="2019-07-16" reportType="RRI_modelConfig" reportId="123e4567-e89b-12d3-a456-426655440000" seqNumber="1" dateTime="2019-07-16T16: 34:50Z" > <modelConfig> <model jurisdictionCode="ES" operatorId="myOperator"
# Released: TBD
# @ 2020 International Gaming Standards Association (IGSA)
# Page 589IGSA Regulatory Reporting Interface V1.0 DRAFT 18
# 7 Land-Based Games
# modelId="G2S" /> <modelConfigDetail modelName="Standard G2S Accounting Model" isDeleted="false" fromDateTime="2018-08-30T14: 25:39Z" /> <modelDefinitionList> <modelDefinition transClass="G2S_cabinet" transType="G2S_wageredCashableAmt" /> <modelDefinition transClass="G2S_cabinet" transType="G2S_egmPaidGameWonAmt" /> <modelDefinition transClass="G2S_cabinet" transType="G2S_handPaidGameWonAmt" /> <modelDefinition transClass="G2S_cabinet" transType="G2S_gamesSinceInitCnt" /> <modelDefinition
# 3.9160829
# com
# sCore
# 176sCore NCEMS Integration Guide
# COMTRADE GAMING
# <figure><table><tr><th>SAS event type ID</th><th>SAS event type context*</th><th>G2S event type code</th><th>G2S event type description</th></tr><tr><td>4E</td><td>Bills_Info_Accepted_500_4E</td><td>G2S_NAE114</td><td>Note stacked.</td></tr><tr><td>4F</td><td>Bills_Info_Accepted_Any_4F</td><td>G2S_NAE114</td><td>Note stacked.</td></tr><tr><td>50</td><td>Bills_Info_Accepted_200_50</td><td>G2S_NAE114</td><td>Note stacked.</td></tr><tr><td>69</td><td>AFT_Info_TransferCompleted_69</td><td>G2S_BNE104</td><td>Bonus award paid.</td></tr><tr><td>11</td><td>Doors_Tilt_DoorOpened_Main_11</td><td>G2S_CBE307</td><td>Cabinet door opened.</td></tr><tr><td>1D</td><td>Doors_Tilt_DoorOpened_Belly_1D</td><td>G2S_CBE305</td><td>Auxiliary door opened.</td></tr><tr><td>15</td><td>Doors_Tilt_DoorOpened_CardCage_15</td><td>G2S_CBE303</td><td>Logic door opened.</td></tr><tr><td>12</td><td>Doors_Info_DoorClosed_Main_12</td><td>G2S_CBE308</td><td>Cabinet door closed.</td></tr><tr><td>7A</td><td>Mem_Info_MetersReset_7A</td><td>G2S_CBE320</td><td>Operator&#x27;s cabinet reset.
# 3.853293
# com
# sCore
# 5sCore NCEMS Integration Guide
# COMTRADE GAMING
# <figure><table><tr><td>A.2.3 RRI compliance</td><td>168</td></tr><tr><td>A.2.4 Data delivery aspects</td><td>171</td></tr><tr><td>A.3 Payment service provider codes</td><td>172</td></tr><tr><td>A.4 SAS-to-G2S mapping of meter domain and meter type codes</td><td>173</td></tr><tr><td>A.5 SAS-to-G2S mapping of event type codes</td><td>176</td></tr></table></figure>
# www.comtradegaming.com
# sCore
# 6sCore NCEMS Integration Guide
# COMTRADE GAMING
# About this document
# Document editions are presented in the following table.
# <figure><table><tr><th>Date</th><th>Edition no.</th><th>Update summary</th></tr><tr><td>05.08.2022</td><td>n/a</td><td>Preliminary incomplete edition: &quot;Introduction to Integration for Operators&quot; (chapter 1 of the upcoming integration guide).</td></tr><tr><td>28.11.2022</td><td>1.0</td><td>Initial release edition.</td></tr><tr><td>07.07.2023</td><td>1.1</td><td>Updated edition with refreshed CCS operator API reference and newly introduced FAQ section (based on questions that arose with operators).
# 3.716198
# </td><td>Count</td></tr></table></figure>
# Table 7B.10 Accounting Model for G2S Bonus Class (G2S_bonus)
# <figure><table><tr><th>Transaction Type</th><th>Description</th><th>Type</th></tr><tr><td>G2S_cashableInAmt</td><td>Value of cashable credits transferred in.</td><td>Amount</td></tr><tr><td>G2S_promo InAmt</td><td>Value of promo credits transferred in.</td><td>Amount</td></tr><tr><td>G2S_nonCashInAmt</td><td>Value of non-cashable credits transferred in.</td><td>Amount</td></tr><tr><td>G2S_transferInCnt</td><td>Count of transfers in.</td><td>Count</td></tr></table></figure>
# Table 7B.11 Accounting Model for G2S Voucher Class (G2S_voucher)
# <figure><table><tr><th>Transaction Type</th><th>Description</th><th>Type</th></tr><tr><td>G2S_cashableInAmt</td><td>Value of cashable credits transferred in.</td><td>Amount</td></tr><tr><td>G2S_cashableInCnt</td><td>Count of cashable credits transferred in.</td><td>Count</td></tr><tr><td>G2S_promo InAmt</td><td>Value of promo credits transferred in.</td><td>Amount</td></tr><tr><td>G2S_promoInCnt</td><td>Count of promo credits transferred in.
# 3.521814
# 2 Gaming Machine Configuration Example
# The following example demonstrates the construction of a gameConfig element when it is used to report the configuration information for a Land-Based Gaming Machine.
# <gameConfig> <game jurisdictionCode="ES" operatorId="myOperator" game Id="G12345" gameName="ABC Multi-Game Slot" gameCategory="RRI_landSlot" gameType="RRI_multiGame" gameVariant="RRI_none" />
# <supplier jurisdictionCode="ES" operatorId="myOperator" supplierId="mySupplier" supplierName="My Supplier" />
# <gameConfigDetail isDeleted="false" fromDateTime="2018-08-30T14:25:39Z" > <landSlotConfig releaseNum="ABC_multiGame_1.1.3" regulatorCategory="B1" regulatorNum="REG102938" theme Id="ABC_myTheme1" paytableId="ABC_myPaytable1" minBet="0.05" maxBet="5.00" minRTP="85.00" maxRTP="96.00" regulatorCategory="B2" downloadServer="" centralServer="" >
# <model jurisdictionCode="ES" operatorId="myOperator" modelId="G2S" /> </landSlotConfig> </gameConfigDetail> </gameConfig>
# Released: TBD
# @ 2020 International Gaming Standards Association (IGSA)
# Page 6557B Land-Based Gaming Machines
# IGSA Regulatory Reporting Interface V1.
# 3.4355378
# <associatedData> <player jurisdictionCode="ES" operatorId="myOperator" playerId="P12345" /> <playerCardActivityData cardIdentifier="09900101988" exception="" /> </associatedData> <snapshotMeterList endDateTime="2018-05-02T12: 53: 05Z" > <meter transClass="G2S cabinet" transType="G2S_wageredCashableAmt" _
# Released: TBD
# @ 2020 International Gaming Standards Association (IGSA)
# Page 659IGSA Regulatory Reporting Interface V1.0 DRAFT 18
# 7B Land-Based Gaming Machines
# meterValue="555.00" /> <meter transClass="G2S_cabinet" transType="G2S_egmPaidGameWonAmt" meterValue="444.00" /> <meter transClass="G2S_cabinet" transType="G2S_gamesSinceInitCnt" meterValue="111" /> <meter transClass="G2S_gamePlay" transType="G2S_wageredAmt" meterValue="555.00" /> <meter transClass="G2S_gamePlay" transType="G2S_egmPaidGameWonAmt" meterValue="444.00" /> <meter transClass="G2S_gamePlay" transType="G2S_wonCnt" meterValue="55" /> <meter transClass="G2S_gamePlay" transType="G2S_lostCnt" meterValue="56" /> <meter transClass="G2S_gamePlay" transType="G2S_theoPaybackAmt" meterValue="527.25" /> <meter transClass="G2S_gamePlay" transType="G2S_avgPaybackPct" meterValue="9500" /> </ snapshotMeterList> </landEvent>
# 7B.
# 3.4259303
# 4 Terminal Configuration Report Example - Gaming Machine
# The following example demonstrates the construction of an element using the c_terminalConfig complex data type. This is an example for a gaming machine. Gaming machines typically use meters. Thus, rollover values are included in the example.
# <gamingReport version="1.0" jurisdictionCode="ES" operatorId="myOperator" submitterId="ABC"
# Page 582
# @ 2020 International Gaming Standards Association (IGSA)
# Released: TBDIGSA Regulatory Reporting Interface V1.0 DRAFT 18
# 7 Land-Based Games
# partitionId="1" periodType="RRI_day" periodStart="2019-07-16" reportType="RRI_terminalConfig" reportId="123e4567-e89b-12d3-a456-426655440000" seqNumber="1" dateTime="2019-07-16T16: 34:50Z" > <terminalConfig> <terminal jurisdictionCode="ES" operatorId="myOperator" terminalId="9876" /> <supplier jurisdictionCode="ES" operatorId="myOperator" supplierId="ABC" supplierName="My Supplier" /> <location jurisdictionCode="ES" operatorId="myOperator" locationId="myLocation" locationName="My Location" locationAddress="123 Main St, Anywhere, CT" />
# <model jurisdictionCode="ES" operatorId="myOperator" modelId="G2S" />
# 3.4259303
#  Typically, different sets of Transaction Types are used with different Transaction Classes. However, the same Transaction Type may appear in multiple Transaction Classes. The chapters of the RRI specification that address individual Game Categories describe the Transaction Classes and Transaction Types used with the specific Game Categories.
# When reporting values associated with the G2S protocol, the Transaction Class is very important. The same Transaction Types are used with multiple Transaction Classes. Thus, it is important that an endpoint correctly identify the Transaction Class to which a Transaction Type belongs; the Transaction Type itself is not specific enough. In other cases, the Transaction Class is not as important. For example, when reporting S2S table games information, only one Transaction Class is used. However, the Transaction Class must still be reported.
# Page 600
# @ 2020 International Gaming Standards Association (IGSA)
# Released: TBDIGSA Regulatory Reporting Interface V1.0 DRAFT 18
# 7 Land-Based Games
# Table 7.33 c_movementList Attributes
#
# 3.3915813
#  Does not include base paytable win, if any.</td><td>Amount</td></tr><tr><td>G2S_wonCnt</td><td>Number of primary games won by the player.</td><td>Count</td></tr><tr><td>G2S_lostCnt</td><td>Number of primary games lost by the player.</td><td>Count</td></tr><tr><td>G2S tiedCnt</td><td>Number of primary games where there were no credits won or lost.</td><td>Count</td></tr></table></figure>
# Released: TBD
# @ 2020 International Gaming Standards Association (IGSA)
# Page 647IGSA Regulatory Reporting Interface V1.0 DRAFT 18
# 7B Land-Based Gaming Machines
# Table 7B.4 Accounting Model for G2S Game Play Class (G2S_gamePlay)
# <figure><table><tr><th>Transaction Type</th><th>Description</th><th>Type</th></tr><tr><td>G2S_failedCnt</td><td>Number of primary games where no outcome could be determined as the game failed to complete.</td><td>Count</td></tr><tr><td>G2S_avgPaybackPct</td><td>Weighted theoretical payback percentage, with two implied decimal places. For example, an 88.65% payback is expressed is 8865. If sum of wager meters is 0 (zero), set to 0 (zero).
# 3.3915813
# </td><td>Count</td></tr></table></figure>
# Table 7B.7 Accounting Model for G2S Hopper Class (G2S_hopper)
# <figure><table><tr><th>Transaction Type</th><th>Description</th><th>Type</th></tr><tr><td>G2S_currencyOutAmt</td><td>Value of currency dispensed by the EGM recorded as cashable credits.</td><td>Amount</td></tr><tr><td>G2S_currencyOutCnt</td><td>Count of currency dispensed by the EGM.</td><td>Count</td></tr><tr><td>G2S_dispDoorOpenCnt</td><td>Count of legal and illegal dispenser door opens.</td><td>Count</td></tr><tr><td>G2S_promoOutAmt</td><td>Value of currency dispensed by the EGM recorded as promotional credits.</td><td>Amount</td></tr><tr><td>G2S_nonCashOutAmt</td><td>Value of currency dispensed by the EGM recorded as non- cashable credits.</td><td>Amount</td></tr><tr><td>G2S_powerOffDispDoorOpenCnt</td><td>Count of power off dispenser door open detections.</td><td>Count</td></tr><tr><td>G2S_illegalDispDoorOpenCnt</td><td>Count of illegal dispenser door opens.</td><td>Count</td></tr></table></figure>
# Table 7B.8 Accounting Model for G2S Note Dispenrer Class (G2S_noteDispenser)
# <figure><table><tr><th>Transaction
# 3.3915813
# 11 Accounting Model for G2S Voucher Class (G2S_voucher)
# <figure><table><tr><th>Transaction Type</th><th>Description</th><th>Type</th></tr><tr><td>G2S_promoOutAmt</td><td>Value of promo credits transferred out.</td><td>Amount</td></tr><tr><td>G2S_promoOutCnt</td><td>Count of promo credit vouchers issued.</td><td>Count</td></tr><tr><td>G2S_nonCashOutAmt</td><td>Value of non-cashable credits transferred out.</td><td>Amount</td></tr><tr><td>G2S_nonCashOutCnt</td><td>Count of non-cashable credit vouchers issued.</td><td>Count</td></tr></table></figure>
# Table 7B.12 Accounting Model for G2S Wagering Account Transfer Class (G2S_wat)
# <figure><table><tr><th>Transaction Type</th><th>Description</th><th>Type</th></tr><tr><td>G2S_cashableInAmt</td><td>Value of cashable credits transferred in.</td><td>Amount</td></tr><tr><td>G2S_promo InAmt</td><td>Value of promo credits transferred in.</td><td>Amount</td></tr><tr><td>G2S_nonCashInAmt</td><td>Value of non-cashable credits transferred in.</td><td>Amount</td></tr><tr><td>G2S_transferInCnt</td><td>Count of transfers in.
# 3.3915813
# 14 Accounting Model for G2S Smart Card Class (G2S_smartCard)
# <figure><table><tr><th>Transaction Type</th><th>Description</th><th>Type</th></tr><tr><td>G2S_cashableOutAmt</td><td>Value of cashable credits transferred out.</td><td>Amount</td></tr><tr><td>G2S_promoOutAmt</td><td>Value of promo credits transferred out.</td><td>Amount</td></tr><tr><td>G2S_nonCashOutAmt</td><td>Value of non-cashable credits transferred out.</td><td>Amount</td></tr><tr><td>G2S_transferOutCnt</td><td>Count of transfers out.</td><td>Count</td></tr></table></figure>
# Table 7B.15 Accounting Model for G2S Mystery Jackpot Class (G2S_mystery)
# <figure><table><tr><th>Transaction Type</th><th>Description</th><th>Type</th></tr><tr><td>G2S_cashableInAmt</td><td>Value of cashable credits transferred in.</td><td>Amount</td></tr><tr><td>G2S_promo InAmt</td><td>Value of promo credits transferred in.</td><td>Amount</td></tr><tr><td>G2S_nonCashInAmt</td><td>Value of non-cashable credits transferred in.</td><td>Amount</td></tr><tr><td>G2S_transferInCnt</td><td>Count of transfers in.</td><td>Count</td></tr><tr><td>G2S_wageredAmt</td><td>Money wagered against games that contribute to the
# 3.2525747
# </td><td>Count</td></tr><tr><td>G2S_promoSysInAmt</td><td>Value of promo credits from redeemed system created vouchers.</td><td>Amount</td></tr><tr><td>G2S_promoSysInCnt</td><td>Count of redeemed system created promo credit vouchers.</td><td>Count</td></tr><tr><td>G2S_nonCashSysInAmt</td><td>Value of non-cashable credits from redeemed system created vouchers.</td><td>Amount</td></tr><tr><td>G2S_nonCashSysInCnt</td><td>Count of redeemed system created non-cashable credit vouchers.</td><td>Count</td></tr><tr><td>G2S_cashableOutAmt</td><td>Value of cashable credits transferred out.</td><td>Amount</td></tr><tr><td>G2S_cashableOutCnt</td><td>Count of cashable credit vouchers issued.</td><td>Count</td></tr></table></figure>
# Released: TBD
# @ 2020 International Gaming Standards Association (IGSA)
# Page 6517B Land-Based Gaming Machines
# IGSA Regulatory Reporting Interface V1.0 DRAFT 18
# Table 7B.11 Accounting Model for G2S Voucher Class (G2S_voucher)
# <figure><table><tr><th>Transaction Type</th><th>Description</th><th>Type</th></tr><tr><td>G2S_promoOutAmt</td><td>Value of promo credits transferred out.
# 2.9683993
# </td><td>Amount</td></tr><tr><td>G2S_nonCashToDropAmt</td><td>Value of currency diverted to the drop box recorded as non- cashable credits.</td><td>Amount</td></tr><tr><td>G2S_nonCashToDispAmt</td><td>Value of currency diverted to the hopper recorded as non- cashable credits.</td><td>Amount</td></tr><tr><td>G2S_powerOffDropDoorOpenCnt</td><td>Count of power off drop door open detections.</td><td>Count</td></tr><tr><td>G2S_illegalDropDoorOpenCnt</td><td>Count of illegal drop door opens.</td><td>Count</td></tr></table></figure>
# Table 7B.6 Accounting Model for G2S Note Acceptor Class (G2S_noteAcceptor)
# <figure><table><tr><th>Transaction Type</th><th>Description</th><th>Type</th></tr><tr><td>G2S_currencyInAmt</td><td>Value of currency accepted by the EGM recorded as cashable credits.</td><td>Amount</td></tr><tr><td>G2S_currencyInCnt</td><td>Count of currency accepted by the EGM.</td><td>Count</td></tr><tr><td>G2S_currencyToDropAmt</td><td>Value of currency diverted to the note stacker recorded as cashable credits.</td><td>Amount</td></tr><tr><td>G2S_currencyToDropCnt</td><td>Count of currency diverted to the note stacker.
# 2.9683993
# 16:23</td><td>21/09/2023 02:00</td><td>:</td></tr></table></figure>
# Figure 9: The Access tokens page of sCore CCS Back Office Operator Portal
# 6. In the Active access tokens table, locate the desired access token with the help of its label.
# 7. In the corresponding table row, in the rightmost column, click Revoke or click the : (action menu) icon and then select Revoke.
# 8. In the Are you sure? dialog box, click Yes. A notification informs you about successful access token revocation. The token can now no longer be used.
# www.comtradegaming.com
# sCore
# 163 :selected:sCore NCEMS Integration Guide
# COMTRADE GAMING
# A. Appendix
# This appendix lists descriptions of CCS response statuses for HTTP requests of an operator's CMS. It also includes questions and answers related to potential operators' integration difficulties. Furthermore, it provides a list of payment service provider codes that can be used with specific transaction types in RRI_playerActivity reports. Finally, it presents mapping of codes for types of land-based gaming terminal meters and events as defined by the SAS protocol specification to corresponding codes as defined by the G2S protocol specification.
# 2.8934155
# 8 Accounting Model for G2S Note Dispenrer Class (G2S_noteDispenser)
# <figure><table><tr><th>Transaction Type</th><th>Description</th><th>Type</th></tr><tr><td>G2S_currencyOutAmt</td><td>Value of currency dispensed by the EGM recorded as cashable credits.</td><td>Amount</td></tr><tr><td>G2S_currencyOutCnt</td><td>Count of currency dispensed by the EGM.</td><td>Count</td></tr><tr><td>G2S_dispDoorOpenCnt</td><td>Count of legal and illegal dispenser door opens.</td><td>Count</td></tr><tr><td>G2S_promoOutAmt</td><td>Value of currency dispensed by the EGM recorded as promotional credits.</td><td>Amount</td></tr><tr><td>G2S_nonCashOutAmt</td><td>Value of currency dispensed by the EGM recorded as non- cashable credits.</td><td>Amount</td></tr><tr><td>G2S_powerOffDispDoorOpenCnt</td><td>Count of power off dispenser door open detections.</td><td>Count</td></tr><tr><td>G2S_illegalDispDoorOpenCnt</td><td>Count of illegal dispenser door opens.</td><td>Count</td></tr></table></figure>
# Page 650
# @ 2020 International Gaming Standards Association (IGSA)
# Released: TBDIGSA Regulatory Reporting Interface V1.
# 2.8934155
# ...
# IGSA Contact Information
# E-mail: sec@igsa.org
# WWW: http://www.igsa.orgIGSA Regulatory Reporting Interface V1.0 DRAFT 18
# Table of Contents
# <figure><table><tr><td>Table of Contents</td><td></td></tr><tr><td>I About This Document</td><td>vii</td></tr><tr><td>I.
# 2.671621
# 3 Accounting Model for G2S Cabinet Class (G2S_cabinet)
# <figure><table><tr><th>Transaction Type</th><th>Description</th><th>Type</th></tr><tr><td>G2S_playerCashableAmt</td><td>Value of cashable credit meter.</td><td>Amount</td></tr><tr><td>G2S_playerPromoAmt</td><td>Value of promo credit meter.</td><td>Amount</td></tr><tr><td>G2S_playerNonCashAmt</td><td>Value of non-cashable credit meter.</td><td>Amount</td></tr><tr><td>G2S_wageredCashableAmt</td><td>Cashable credits wagered on the EGM.</td><td>Amount</td></tr><tr><td>G2S_wageredPromoAmt</td><td>Cashable promotional credits wagered on the EGM.</td><td>Amount</td></tr><tr><td>G2S_wageredNonCashAmt</td><td>Non-cashable credits wagered on the EGM.</td><td>Amount</td></tr><tr><td>G2S_egmPaidGameWonAmt</td><td>Total EGM paid base paytable win from game play.</td><td>Amount</td></tr><tr><td>G2S_handPaidGameWonAmt</td><td>Total hand paid base paytable win from game play.</td><td>Amount</td></tr><tr><td>G2S_egmPaidProgWonAmt</td><td>Total EGM paid progressive win.</td><td>Amount</td></tr><tr><td>G2S_handPaidProgWonAmt</td><td>Total hand paid progressive win.
# 2.6364112
# </td><td>Count</td></tr><tr><td>G2S_cashableOutAmt</td><td>Value of cashable credits transferred out.</td><td>Amount</td></tr><tr><td>G2S_promoOutAmt</td><td>Value of promo credits transferred out.</td><td>Amount</td></tr><tr><td>G2S_nonCashOutAmt</td><td>Value of non-cashable credits transferred out.</td><td>Amount</td></tr><tr><td>G2S_transferOutCnt</td><td>Count of transfers out.</td><td>Count</td></tr></table></figure>
# Table 7B.5 Accounting Model for G2S Coin Acceptor Class (G2S_coinAcceptor)
# <figure><table><tr><th>Transaction Type</th><th>Description</th><th>Type</th></tr><tr><td>G2S_currencyInAmt</td><td>Value of currency accepted by the EGM recorded as cashable credits.</td><td>Amount</td></tr><tr><td>G2S_currencyInCnt</td><td>Count of currency accepted by the EGM.</td><td>Count</td></tr><tr><td>G2S_currencyToDropAmt</td><td>Value of currency diverted to the drop box recorded as cashable credits.</td><td>Amount</td></tr><tr><td>G2S_currencyToDropCnt</td><td>Count of currency diverted to the drop box.</td><td>Count</td></tr></table></figure>
# Page 648
# @ 2020 International Gaming Standards Association (IGSA)
# Released: TBDIGSA Regulatory Reporting Interface V1.
# 2.6364112
# </td><td>Count</td></tr><tr><td>G2S_promo InAmt</td><td>Value of currency accepted by the EGM recorded as promotional credits.</td><td>Amount</td></tr><tr><td>G2S_promoToDropAmt</td><td>Value of currency diverted to the note stacker recorded as promotional credits.</td><td>Amount</td></tr><tr><td>G2S_promoToDispAmt</td><td>Value of currency diverted to the note dispenser recorded as promotional credits.</td><td>Amount</td></tr></table></figure>
# Released: TBD
# @ 2020 International Gaming Standards Association (IGSA)
# Page 649IGSA Regulatory Reporting Interface V1.0 DRAFT 18
# 7B Land-Based Gaming Machines
# Table 7B.6 Accounting Model for G2S Note Acceptor Class (G2S_noteAcceptor)
# <figure><table><tr><th>Transaction Type</th><th>Description</th><th>Type</th></tr><tr><td>G2S_nonCashInAmt</td><td>Value of currency accepted by the EGM recorded as non- cashable credits.</td><td>Amount</td></tr><tr><td>G2S_nonCashToDropAmt</td><td>Value of currency diverted to the note stacker recorded as non-cashable credits.</td><td>Amount</td></tr><tr><td>G2S_nonCashToDispAmt</td><td>Value of currency diverted to the note dispenser
# 2.6364112
# 15 Accounting Model for G2S Mystery Jackpot Class (G2S_mystery)
# <figure><table><tr><th>Transaction Type</th><th>Description</th><th>Type</th></tr><tr><td>G2S_cashableInAmt</td><td>Value of cashable credits transferred in.</td><td>Amount</td></tr><tr><td>G2S_promo InAmt</td><td>Value of promo credits transferred in.</td><td>Amount</td></tr><tr><td>G2S_nonCashInAmt</td><td>Value of non-cashable credits transferred in.</td><td>Amount</td></tr><tr><td>G2S_transferInCnt</td><td>Count of transfers in.</td><td>Count</td></tr><tr><td>G2S_wageredAmt</td><td>Money wagered against games that contribute to the jackpots.</td><td>Amount</td></tr><tr><td>G2S_playedCnt</td><td>Count of the wagers made against games that contribute to the jackpots.</td><td>Count</td></tr></table></figure>
# 7B.3.4 SAS Transaction Classes & Transaction Types
# When movements originate from games communicating via the SAS protocol, the Transaction Types reported using this specification should be constructed by appending the hexadecimal representation of the SAS meter to "SAS_" - for example, SAS_001C.
# 2.6364112
# com
# sCore
# 116sCore NCEMS Integration Guide
# COMTRADE GAMING
# <figure><table><tr><th>Event type (G2S protocol)</th><th>Description</th></tr><tr><td>G2S_CBE318</td><td>Power-off - auxiliary door opened.</td></tr><tr><td>G2S_CBE319</td><td>Power-off - cabinet door opened.</td></tr><tr><td>G2S_CBE006</td><td>Device configuration changed by operator.</td></tr><tr><td>G2S_DFE105</td><td>Transfer successfully completed.</td></tr><tr><td>G2S_HPE109</td><td>Extra coins paid.</td></tr><tr><td>G2S_HPE113</td><td>Coins dispensed.</td></tr><tr><td>G2S_MPE104</td><td>Mystery jackpot awarded.</td></tr><tr><td>G2S_PGE104</td><td>Progressive committed.</td></tr><tr><td>G2S_VCE108</td><td>Voucher redeemed.</td></tr><tr><td>G2S_VCE103</td><td>Voucher issued.</td></tr></table></figure>
# Example report
# The following is an example construction of the RRI_landEvent report for a single event that took place in a connected land-based gaming terminal (RRI_landSlot):
# <rri : gamingReport xmlns : rri="urn : GSA : RRI : 1.0: GSA: rri" xmlns : xsi="http://www.
# 2.5422623
#
# In many cases, the Transaction Types used with land-based games map directly to commonly used values from other protocols, such as the S2S and G2S protocols from GSA, where they are often referred to as "meters".
# Most movements (movementValue) are reported as positive values. However, some movements, such as the EGM credit meter, may be reported as positive or negative values depending on the direction of the movements for the period.
# The "meter" model also allows non-monetary movements, such as counts and percentages, to be reported. The type of movement being reported - amount (monetary), count, or percentage - is not explicit. It is specified in the definition of the Transaction Type.
# Transaction Types are organized into "classes". The Transaction Class (transClass) identifies the class or domain to which a Transaction Type belongs - for example, the cabinet class, voucher class, or table-games class. Typically, different sets of Transaction Types are used with different Transaction Classes. However, the same Transaction Type may appear in multiple Transaction Classes.
# 2.5422623
# </td><td>Count</td></tr><tr><td>G2S_powerOffCabinetDoorOpenCnt</td><td>Count of power off cabinet door open detections.</td><td>Count</td></tr><tr><td>G2S_occupancy</td><td>Amount of time (in milliseconds) that the EGM was occupied.</td><td>Count</td></tr><tr><td>G2S_idReaderErrorCnt</td><td>Number of errors detected while reading IDs.</td><td>Count</td></tr></table></figure>
# Page 646
# @ 2020 International Gaming Standards Association (IGSA)
# Released: TBDIGSA Regulatory Reporting Interface V1.0 DRAFT 18
# 7B Land-Based Gaming Machines
# Table 7B.3 Accounting Model for G2S Cabinet Class (G2S_cabinet)
# <figure><table><tr><th>Transaction Type</th><th>Description</th><th>Type</th></tr><tr><td>G2S_auditWinAmt</td><td>Sum of paytable win amounts that resulted in the generation of Audit Win Pending events.</td><td>Amount</td></tr><tr><td>G2S_auditWinCnt</td><td>Count of Audit Win Pending events.</td><td>Count</td></tr><tr><td>G2S_significantWinAmt</td><td>Sum of paytable win amounts that resulted in the generation of Significant Win events.
# 2.5422623
# 3 Accounting Model for G2S Cabinet Class (G2S_cabinet)
# <figure><table><tr><th>Transaction Type</th><th>Description</th><th>Type</th></tr><tr><td>G2S_auditWinAmt</td><td>Sum of paytable win amounts that resulted in the generation of Audit Win Pending events.</td><td>Amount</td></tr><tr><td>G2S_auditWinCnt</td><td>Count of Audit Win Pending events.</td><td>Count</td></tr><tr><td>G2S_significantWinAmt</td><td>Sum of paytable win amounts that resulted in the generation of Significant Win events.</td><td>Amount</td></tr><tr><td>G2S_significantWinCnt</td><td>Count of Significant Win events.</td><td>Count</td></tr><tr><td>G2S_logicSealBrokenCnt</td><td>Number of times the logic seal was broken.</td><td>Count</td></tr><tr><td>G2S_illegalLogicDoorOpenCnt</td><td>Number of illegal logic door opens.</td><td>Count</td></tr><tr><td>G2S_illegalAuxDoorOpenCnt</td><td>Number of illegal auxiliary door opens.</td><td>Count</td></tr><tr><td>G2S_illegalCabinetDoorOpenCnt</td><td>Number of illegal cabinet door opens.</td><td>Count</td></tr><tr><td>G2S_mjtGamesPlayedCnt</td><td>Total number of games played while the MJT bo-nus mode was active.
# 2.5422623
# </td><td>Count</td></tr><tr><td>G2S_mjtGamesPlayedCnt</td><td>Total number of games played while the MJT bo-nus mode was active.</td><td>Count</td></tr><tr><td>G2S_mjtGamesPaidCnt</td><td>Total number of games awarded an MJT bonus while the MJT bonus mode was active.</td><td>Count</td></tr><tr><td>G2S_mjtBonusAmt</td><td>Total amount of MJT bonuses paid.</td><td>Amount</td></tr><tr><td>G2S_wmGamesPlayedCnt</td><td>Total number of games played while the Wager Match bonus mode was active.</td><td>Count</td></tr><tr><td>G2S_wmBonusAmt</td><td>Total amount of transfers from the Wager Match escrow balance.</td><td>Amount</td></tr></table></figure>
# Table 7B.4 Accounting Model for G2S Game Play Class (G2S_gamePlay)
# <figure><table><tr><th>Transaction Type</th><th>Description</th><th>Type</th></tr><tr><td>G2S_wageredAmt</td><td>Total amount wagered.</td><td>Amount</td></tr><tr><td>G2S_egmPaidGameWonAmt</td><td>EGM paid base paytable win from game play (final win following primary game and secondary game play). Does not include win from external bonus awards or progressives.
# 2.445573
# 4 Accounting Model for G2S Game Play Class (G2S_gamePlay)
# <figure><table><tr><th>Transaction Type</th><th>Description</th><th>Type</th></tr><tr><td>G2S_wageredAmt</td><td>Total amount wagered.</td><td>Amount</td></tr><tr><td>G2S_egmPaidGameWonAmt</td><td>EGM paid base paytable win from game play (final win following primary game and secondary game play). Does not include win from external bonus awards or progressives.</td><td>Amount</td></tr><tr><td>G2S_handPaidGameWonAmt</td><td>Hand paid base paytable win from game play (final win following primary game and any secondary game play). Does not include win from external bonus awards or progressives.</td><td>Amount</td></tr><tr><td>G2S_egmPaidProgWonAmt</td><td>EGM paid progressive win, resulting from game play. Does not include base paytable win, if any.</td><td>Amount</td></tr><tr><td>G2S_handPaidProgWonAmt</td><td>Hand paid progressive win, resulting from game play. Does not include base paytable win, if any.</td><td>Amount</td></tr><tr><td>G2S_wonCnt</td><td>Number of primary games won by the player.
# 2.445573
# 4 Accounting Model for G2S Game Play Class (G2S_gamePlay)
# <figure><table><tr><th>Transaction Type</th><th>Description</th><th>Type</th></tr><tr><td>G2S_failedCnt</td><td>Number of primary games where no outcome could be determined as the game failed to complete.</td><td>Count</td></tr><tr><td>G2S_avgPaybackPct</td><td>Weighted theoretical payback percentage, with two implied decimal places. For example, an 88.65% payback is expressed is 8865. If sum of wager meters is 0 (zero), set to 0 (zero).</td><td>Percent</td></tr><tr><td>G2S_secWageredAmt</td><td>Initial amounts wagered on secondary game cycles, such as double-up features.</td><td>Amount</td></tr><tr><td>G2S_secWonAmt</td><td>Final amounts won on secondary game cycles.</td><td>Amount</td></tr><tr><td>G2S_secWonCnt</td><td>Count of secondary games won by the player.</td><td>Count</td></tr><tr><td>G2S_secLostCnt</td><td>Count of secondary games lost by the player.</td><td>Count</td></tr><tr><td>G2S_secTiedCnt</td><td>Count of secondary games where there were no credits won or lost.</td><td>Count</td></tr><tr><td>G2S_secFailedCnt</td><td>Count of secondary games where no outcome could
# 2.445573
# 5 Accounting Model for G2S Coin Acceptor Class (G2S_coinAcceptor)
# <figure><table><tr><th>Transaction Type</th><th>Description</th><th>Type</th></tr><tr><td>G2S_currencyToDispAmt</td><td>Value of currency diverted to the hopper recorded as cashable credits.</td><td>Amount</td></tr><tr><td>G2S_currencyToDispCnt</td><td>Count of currency diverted to the hopper.</td><td>Count</td></tr><tr><td>G2S_dropDoorOpenCnt</td><td>Count of legal and illegal drop door opens.</td><td>Count</td></tr><tr><td>G2S_promo InAmt</td><td>Value of currency accepted by the EGM recorded as promotional credits.</td><td>Amount</td></tr><tr><td>G2S_promoToDropAmt</td><td>Value of currency diverted to the drop box recorded as promotional credits.</td><td>Amount</td></tr><tr><td>G2S_promoToDispAmt</td><td>Value of currency diverted to the hopper recorded as promotional credits.</td><td>Amount</td></tr><tr><td>G2S_nonCashInAmt</td><td>Value of currency accepted by the EGM recorded as non- cashable credits.</td><td>Amount</td></tr><tr><td>G2S_nonCashToDropAmt</td><td>Value of currency diverted to the drop box recorded as non- cashable credits.
# 2.445573
# </td></tr></table></figure>
# A terminal subelement must have the following attributes:
# <figure><table><tr><th>Attribute</th><th>Data type</th><th>Description</th></tr><tr><td>terminalId</td><td>t_terminalId</td><td>Identifier of the gaming terminal.</td></tr></table></figure>
# An event element must have the following attributes:
# <figure><table><tr><th>Attribute</th><th>Data type</th><th>Description</th></tr><tr><td>eventId</td><td>t_eventId</td><td>Identifier of the event.</td></tr><tr><td>eventCode</td><td>t_eventCode</td><td>Standardized code* for type of the event.</td></tr><tr><td>eventText</td><td>description</td><td>Brief description of the event.</td></tr><tr><td>eventDateTime</td><td>t_dateTime</td><td>Date and time of the moment when the event took place.</td></tr></table></figure>
# The set of standardized event type codes (valid values of the t_eventCode enumeration data type) that you should use is defined in the G2S protocol specification. The gaming terminal, connected to the operator's CMS either directly or through a SMIB, should report all required events.
# 2.3159366
#  it presents mapping of codes for types of land-based gaming terminal meters and events as defined by the SAS protocol specification to corresponding codes as defined by the G2S protocol specification.
# A.1 HTTP response status reference
# This section lists statuses that the regulator's CCS (NCEMS) can return in HTTP response messages to inform the operator's CMS about HTTP request results. For each status, its code and meaning are specified and remarks about potential causes and resolutions are provided.
# A.1.1 Common responses
# Statuses in HTTP responses of the CCS to any HTTP request are the following:
# <figure><table><tr><th>Code</th><th>Meaning</th><th>Remarks</th></tr><tr><td>400</td><td>Malformed request message.</td><td>Potential causes: - spelling errors in the request message - missing request parameters - invalid body parameters - invalid resource (entity) identifiers - parameters outside of domain range - wrong preconditions for resource (entity) states The client should not repeat the request without modifications.
# :unselected: :unselected: :unselected: :unselected: :unselected: :unselected:</td></tr><tr><td rowSpan=2>401</td><td rowSpan=2>Unauthorized access attempt.
